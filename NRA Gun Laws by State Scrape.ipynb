# %% [markdown]
# ## NRA Web Scraping
# This is a a quick scraping script which scrapes data from the NRA website to create a dataset containing gun laws for all 50 states and the district of columbia. It works well and there are no missing values as of 10/27/2016. The section of data cleaning may need to be tweaked down the line as data on their site is modified, but as of now it works perfectly. The script produces the 3 csv files listed below:<br>
#
# - 'NRA_Gun_Laws_by_State_CHAR.csv' - This is a table with the gun laws by state and their character description.
# - 'NRA_Gun_Laws_by_State_NUM.csv' - This is a table with the gun laws by state with a numeric value in place of the character value.
# - 'NRA_Gun_Laws_by_State_LEGEND.csv' - This table describes what numeric values correspond to the character values
# <br> <br>
# Both the Numeric and Character version have the states clustered on strictness of gun laws

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
#Create List of States
states = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', \
          'district-of-columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', \
          'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', \
          'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New-Hampshire', 'New-Jersey', 'New-Mexico', \
          'New-York', 'North-Carolina', 'North-Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode-Island', \
          'South-Carolina', 'South-Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', \
          'West-Virginia', 'Wisconsin', 'Wyoming']

states_dict = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West-Virginia',
        'WY': 'Wyoming'
}

#Lowercase all values in list
states = [x.lower() for x in states]

#Innitialize dict
gun_laws = dict.fromkeys(states)

# %%
#Set Base URL
url = "https://www.nraila.org/gun-laws/state-gun-laws/{}/"

# %%
#Create Sub-dict for each state
for x in gun_laws.keys(): gun_laws[x]=dict()

# %%
for s in range(len(states)):
    #Pull Site
    result = requests.get(url.format(states[s]))

    #Parse
    c = result.content
    soup = BeautifulSoup(result.text,"lxml")

    #first table names
    rifle = [x.get_text()+" (Rifle-Shotgun):" for x in soup.find_all("tbody")[0].find_all("td",{"class":"title"})]
    handgun = [x.get_text()+": (Handgun):" for x in soup.find_all("tbody")[0].find_all("td",{"class":"title"})]
    riflehandgun = []
    for i in range(len(rifle)):
        riflehandgun.append(rifle[i])
        riflehandgun.append(handgun[i])
    #make the first column
    table_r1 = riflehandgun+[x.get_text() for x in soup.find_all("tbody")[1].find_all("td",{"class":"title"})]

    #Get the first table values
    t1 = soup.find_all("tbody")[0].find_all("td",{"class":None})
    #Get the Text
    t1 = [x.get_text() for x in t1]
    #Get the first table values
    t2 = soup.find_all("tbody")[1].find_all("td",{"class":None})
    #Get the Text
    t2 = [x.get_text() for x in t2]
    #Full List of Answers
    t3 = t1+t2
    #Put it into the State Dict
    for i in range(len(t3)):
        gun_laws[states[s]][table_r1[i]] = t3[i]

# %%
#Create DataFrame
gun_laws_df = pd.DataFrame(gun_laws).T
#gun_laws_df.to_csv("gun_laws_by_state_scrape_dirty.csv")

# %%
#Summary of DataFrame
gun_laws_df.describe().T.sort_values(by="count", ascending=False)
# Out:
#                                                    count unique  \
# Castle Doctrine                                       51      3
# Permit to Purchase (Rifle-Shotgun):                   51      8
# Permit to Purchase: (Handgun):                        51      7
# Right to Carry in Restaurants                         50      3
# Right to Carry Confidentiality                        50      2
# Right To Carry Reciprocity and Recognition            50      4
# Registration of Firearms: (Handgun):                  50      4
# Registration of Firearms (Rifle-Shotgun):             50      4
# Right to Keep & Bear Arms State Constitutional ...    50      3
# Permit to Carry: (Handgun):                           50      6
# Permit to Carry (Rifle-Shotgun):                      50      5
# No-Net Loss                                           50      2
# Right To Carry Laws                                   49      4
# Licensing of Owners: (Handgun):                       48      4
# Licensing of Owners (Rifle-Shotgun):                  48      5
# Licensing of Owner (Rifle-Shotgun):                    3      2
# Licensing of Owner: (Handgun):                         3      2
# Right to Carry Laws                                    2      2
# Registration of Firearms*: (Handgun):                  1      1
# Permit to possess registered "Assault Weapons":...     1      1
# Right To Carry Confidentiality                         1      1
# Permit to possess registered "Assault Weapons" ...     1      1
# Right To Carry in Restaurants                          1      1
# Right To Keep & Bear Arms State Constitutional ...     1      1
# Right to Carry Reciprocity and Recognition             1      1
# Registration of Firearms* (Rifle-Shotgun):             1      1
#
#                                                                      top freq
# Castle Doctrine                                                  Enacted   33
# Permit to Purchase (Rifle-Shotgun):                                   No   42
# Permit to Purchase: (Handgun):                                        No   35
# Right to Carry in Restaurants                                      Legal   26
# Right to Carry Confidentiality                        Provisions Enacted   39
# Right To Carry Reciprocity and Recognition          Outright Recognition   17
# Registration of Firearms: (Handgun):                                  No   41
# Registration of Firearms (Rifle-Shotgun):                             No   45
# Right to Keep & Bear Arms State Constitutional ...       With Provisions   42
# Permit to Carry: (Handgun):                                          Yes   35
# Permit to Carry (Rifle-Shotgun):                                      No   46
# No-Net Loss                                               No Legislation   37
# Right To Carry Laws                                          Shall Issue   33
# Licensing of Owners: (Handgun):                                       No   41
# Licensing of Owners (Rifle-Shotgun):                                  No   44
# Licensing of Owner (Rifle-Shotgun):                                   No    2
# Licensing of Owner: (Handgun):                                        No    2
# Right to Carry Laws                                          Shall Issue    1
# Registration of Firearms*: (Handgun):                                 No    1
# Permit to possess registered "Assault Weapons":...                    No    1
# Right To Carry Confidentiality                        Provisions Enacted    1
# Permit to possess registered "Assault Weapons" ...                    No    1
# Right To Carry in Restaurants                                Partial Ban    1
# Right To Keep & Bear Arms State Constitutional ...       With Provisions    1
# Right to Carry Reciprocity and Recognition          Outright Recognition    1
# Registration of Firearms* (Rifle-Shotgun):                            No    1

# %%
#Clean Up the Data

#Fix Alaska
gun_laws_df.iloc[1]["Permit to Carry: (Handgun):"] = "No"
gun_laws_df.iloc[1]["Permit to Carry (Rifle-Shotgun):"] = "No"

#Fix Connecticut
gun_laws_df.iloc[6]["No-Net Loss"] = "Yes"

#Fix Mass
gun_laws_df.iloc[21]["Registration of Firearms: (Handgun):"] = "Yes"
gun_laws_df.iloc[21]["Registration of Firearms (Rifle-Shotgun):"] = "Yes"
gun_laws_df.iloc[21]["Licensing of Owners: (Handgun):"] = "Yes"
gun_laws_df.iloc[21]["Licensing of Owners (Rifle-Shotgun):"] = "Yes"

#Fix California
gun_laws_df.iloc[4]["Licensing of Owners: (Handgun):"] = "No"
gun_laws_df.iloc[4]["Licensing of Owners (Rifle-Shotgun):"] = "No"

#Fix Kansas
gun_laws_df.iloc[16]["Licensing of Owners: (Handgun):"] = "No"
gun_laws_df.iloc[16]["Licensing of Owners (Rifle-Shotgun):"] = "No"

#Fix Missouri
gun_laws_df.iloc[25]["Right to Keep & Bear Arms State Constitutional Provisions"] = "With Provisions"
gun_laws_df.iloc[25]["Right to Carry Confidentiality"] = "Provisions Enacted"
gun_laws_df["Right to Carry in Restaurants"] = "Partial Ban"

#Fix Alabama
gun_laws_df.iloc[0]["Right To Carry Laws"] = "Shall Issue"
gun_laws_df.iloc[0]["Right To Carry Reciprocity and Recognition"] = "Outright Recognition"

#Fix Arizona
gun_laws_df.iloc[2]["Right To Carry Laws"] = "No Permit Required"

#Remove Unnecessary Columns
to_drop = ["Registration of Firearms*: (Handgun):", "Registration of Firearms* (Rifle-Shotgun):",\
"Licensing of Owner: (Handgun):", "Licensing of Owner (Rifle-Shotgun):",\
"Right To Keep & Bear Arms State Constitutional Provisions", "Right to Carry Laws", "Right To Carry Confidentiality",\
"Right To Carry in Restaurants", "Right to Carry Reciprocity and Recognition",\
'Permit to possess registered "Assault Weapons": (Handgun):', 'Permit to possess registered \
"Assault Weapons" (Rifle-Shotgun):']
gun_laws_df = gun_laws_df.drop(to_drop,axis=1)

#create state column
state_dict_exch = {val.lower().replace(' ','-'):key.lower() for (key, val) in states_dict.items()}
gun_laws_df['State'] = [state_dict_exch[x] for x in gun_laws_df.index]

#Correcting Inconsistent Values
toreplace = ['\*',
'FOID Required',
'FID Required',
'ID Card Required',
'Yes \(in incorporated areas and concealed anywhere\)',
'Not Available',
'']

replacement = ['',
'Yes',
'Yes',
'Yes',
'Yes',
'Yes',
'No']

gun_laws_df = gun_laws_df.replace(toreplace, replacement, regex = True)

#Standardize column names
gun_laws_df.columns = [re.sub('&','and',re.sub(':','',x.lower()) )for x in list(gun_laws_df.columns)]

#Fixing CT no-net loss missing values True as of 2009
gun_laws_df['no-net loss'][6] = 'Enacted'

# %%
gun_laws_df.describe().T
# Out:
#                                                    count unique  \
# castle doctrine                                       51      3
# licensing of owners (rifle-shotgun)                   51      2
# licensing of owners (handgun)                         51      2
# no-net loss                                           51      2
# permit to carry (rifle-shotgun)                       51      2
# permit to carry (handgun)                             51      2
# permit to purchase (rifle-shotgun)                    51      2
# permit to purchase (handgun)                          51      2
# registration of firearms (rifle-shotgun)              51      2
# registration of firearms (handgun)                    51      2
# right to carry laws                                   51      4
# right to carry reciprocity and recognition            51      4
# right to carry confidentiality                        51      2
# right to carry in restaurants                         51      1
# right to keep and bear arms state constitutiona...    51      3
# state                                                 51     51
#
#                                                                      top freq
# castle doctrine                                                  Enacted   33
# licensing of owners (rifle-shotgun)                                   No   47
# licensing of owners (handgun)                                         No   45
# no-net loss                                               No Legislation   37
# permit to carry (rifle-shotgun)                                       No   48
# permit to carry (handgun)                                            Yes   42
# permit to purchase (rifle-shotgun)                                    No   45
# permit to purchase (handgun)                                          No   38
# registration of firearms (rifle-shotgun)                              No   46
# registration of firearms (handgun)                                    No   44
# right to carry laws                                          Shall Issue   34
# right to carry reciprocity and recognition          Outright Recognition   18
# right to carry confidentiality                        Provisions Enacted   40
# right to carry in restaurants                                Partial Ban   51
# right to keep and bear arms state constitutiona...       With Provisions   43
# state                                                                 nm    1

# %%
#Creating a new df with numeric values instead of character values
gun_laws_num = gun_laws_df.replace(['No','Yes','Enacted', 'No Law', 'No Legislation', 'None', 
'True Reciprocity', 'Outright Recognition','Conditional Recognition', 'No Permit Required', 
'Shall Issue', 'Discretionary/Reasonable Issue', 'Rights Restricted-Very Limited Issue',
'No Provisions', 'Provisions Enacted', 'Partial Ban', 'With Provisions',
'Partial (duty to retreat from co-habitants)'], 
[1, 4, 1, 4, 4, 4, 1, 2, 3, 1, 2, 3, 4, 1, 4, 1, 2.5, 2.5])

#Creates a Legend for What Numeric Values Mean
legend = pd.DataFrame({'Char':['No','Yes','Enacted', 'No Law', 'No Legislation', 'None', 
'True Reciprocity', 'Outright Recognition','Conditional Recognition', 'No Permit Required', 
'Shall Issue', 'Discretionary/Reasonable Issue', 'Rights Restricted-Very Limited Issue',
'No Provisions', 'Provisions Enacted', 'Partial Ban', 'With Provisions',
'Partial (duty to retreat from co-habitants)'],
'Num':[1, 4, 1, 4, 4, 4, 1, 2, 3, 1, 2, 3, 4, 1, 4, 1, 2.5, 2.5]})

# %%
#Save Clean
# gun_laws_df.to_csv("gun_laws_by_state_scrape_clean.csv")
# gun_laws_df.describe().T.sort_values(by="count", ascending=False)

# %%
gun_laws_num
# Out:
#                       castle doctrine  licensing of owners (rifle-shotgun)  \
# massachusetts                     4.0                                    4
# new-jersey                        2.5                                    4
# connecticut                       1.0                                    4
# california                        4.0                                    1
# hawaii                            4.0                                    1
# illinois                          4.0                                    4
# new-york                          4.0                                    1
# district-of-columbia              4.0                                    1
# maryland                          1.0                                    1
# michigan                          1.0                                    1
# minnesota                         4.0                                    1
# rhode-island                      4.0                                    1
# north-carolina                    1.0                                    1
# iowa                              4.0                                    1
# delaware                          4.0                                    1
# oregon                            4.0                                    1
# kentucky                                                            2.5
# arkansas                                                            2.5
# indiana                                                             2.5
# new-hampshire                                                       2.5
# florida                                                             2.5
# north-dakota                                                        2.5
# wisconsin                                                           2.5
# louisiana                                                           2.5
# colorado                                                            2.5
# georgia                                                             2.5
# west-virginia                                                       2.5
# idaho                                                               2.5
# maine                                                               2.5
# wyoming                                                             2.5
# alaska                                                              2.5
# vermont                                                             2.5
# kansas                                                              2.5
# arizona                                                             2.5
# mississippi                                                         2.5
#
#                      state  sum  rank category
# massachusetts           ma   40     0   Strict
# new-jersey              nj   34     1   Strict
# connecticut             ct   33     2   Strict
# california              ca   31     3   Strict
# hawaii                  hi   31     4   Strict
# illinois                il   29     5   Strict
# new-york                ny   28     6   Strict
# district-of-columbia    dc   28     7   Strict
# maryland                md   28     8   Strict
# michigan                mi   21     9   Strict
# minnesota               mn   19    10   Strict
# rhode-island            ri   19    11   Strict
# north-carolina          nc   18    12   Strict
# iowa                    ia   18    13   Strict
# delaware                de   18    14   Strict
# oregon                  or   17    15   Strict
# nebraska                ne   17    16   Strict
# ohio                    oh   16    17  Average
# washington              wa   16    18  Average
# nevada                  nv   16    19  Average
# montana                 mt   16    20  Average
# virginia                va   16    21  Average
# south-carolina          sc   16    22  Average
# new-mexico              nm   16    23  Average
# texas                   tx   16    24  Average
# pennsylvania            pa   16    25  Average
# utah                    ut   15    26  Average
# tennessee               tn   15    27  Average
# oklahoma                ok   15    28  Average
# south-dakota            sd   15    29  Average
# alabama                 al   15    30  Average
# missouri                mo   15    31  Average
# kentucky                ky   15    32  Average
# arkansas                ar   15    33  Average
# indiana                 in   15    34  Lenient
# new-hampshire           nh   14    35  Lenient
# florida                 fl   14    36  Lenient
# north-dakota            nd   14    37  Lenient
# wisconsin               wi   14    38  Lenient
# louisiana               la   14    39  Lenient
# colorado                co   14    40  Lenient
# georgia                 ga   14    41  Lenient
# west-virginia           wv   13    42  Lenient
# idaho                   id   12    43  Lenient
# maine                   me   12    44  Lenient
# wyoming                 wy   12    45  Lenient
# alaska                  ak   11    46  Lenient
# vermont                 vt   11    47  Lenient
# kansas                  ks   11    48  Lenient
# arizona                 az   11    49  Lenient
# mississippi             ms   11    50  Lenient

# %%
#Add Rank and Sum Columns
gun_laws_num['sum'] = gun_laws_num[[gun_laws_num.columns[i] for i in [1,2,4,5,6,7,8,9,10,-5]]].sum(axis = 1)
gun_laws_num = gun_laws_num.sort_values(by = 'sum', ascending = False)
gun_laws_num['rank'] = list(range(51))

#Break Into Categories and Add Column
gun_laws_num['category'] = ['Strict']*17 + ['Average']*17 + ['Lenient']*17

#Create df with character values and categories
final_gun_laws = pd.concat([gun_laws_df.sort_values(by = 'state'), 
gun_laws_num.iloc[:,-4:].sort_values(by = 'state').iloc[:,-3:]], axis =1)

# %%
#Test Print Statements
#gun_laws_num['category']
#gun_laws_num.iloc[:,-4:].sort_values(by = 'rank').iloc[:,-3:]

# %%
#Output to CSV
final_gun_laws.to_csv('data/NRA_Gun_Laws_by_State_CHAR.csv', index = False)
gun_laws_num.to_csv('data/NRA_Gun_Laws_by_State_NUM.csv', index = False)
legend.to_csv('data/NRA_Gun_Laws_by_State_LEGEND.csv', index = False)
